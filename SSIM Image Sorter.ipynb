# %%
from skimage import measure
import matplotlib.pyplot as plt
import numpy as np
import cv2
import os
import shutil

# %%
#code to sort based on SSIM

#set this to dataset directory
dataset = './Demo/SSIM/unsorted/'

#set this to image extension
extension = ".jpg"
#if you want verbose output, set this to true
verbose = True

#SSIM threshold. A lower thresold (<0.7) will retain less images. A threshold closer to 1.0 will retain more images. 
#Images with an SSIM value of 1.0 are identical.
threshold = 0.7

#if you want to move all the unique images to a separate directory, set this to True
moveFiles = True
#if you set moveFiles to True, provide a name for your new directory
uniqueImPath = './Demo/SSIM/unique/'


datasetDirectory = os.fsencode(dataset)
unique = []
notUnique = []

for eachImage in os.listdir(dataset):
    imageName = os.fsdecode(eachImage)
    imagePath = os.path.join(os.fsdecode(datasetDirectory), imageName)
    if imageName.endswith(extension) and eachImage not in unique and eachImage not in notUnique:
        for eachOtherImage in os.listdir(dataset):
            if verbose == True:
                print("comparing: ", eachImage, " against ", eachOtherImage)
            if eachImage != eachOtherImage and eachOtherImage not in unique and eachOtherImage not in notUnique:
                otherImageName = os.fsdecode(eachOtherImage)
                otherImagePath = os.path.join(os.fsdecode(datasetDirectory), otherImageName)
                if otherImageName.endswith(extension):
                    imageA = cv2.imread(imagePath)
                    imageB = cv2.imread(otherImagePath)
                    if imageA.shape == imageB.shape:
                        score = measure.compare_ssim(imageA, imageB,multichannel=True)
                        if score > threshold:
                            notUnique.append(eachImage)
                            if verbose == True:
                                print(eachImage, "similar to ", eachOtherImage, " with SSIM score: ", score)
                            break
    if eachImage not in notUnique:
        unique.append(eachImage)
        if verbose == True:
            print(eachImage, " unique")
        
if verbose == True:             
    print("Unique ", unique)
    print("Not unique ",notUnique)
    
#all unique images are moved from the 'unsorted' dataset to the 'unique' datasets. The remaining images are left in the 'unsorted' dataset
if moveFiles == True:
    for eachImage in unique:
        imPath = dataset+'/'+eachImage
        uniqueImagesPath = uniqueImPath+'/'+eachImage
        if os.path.exists(imPath):
            shutil.move(imPath, uniqueImagesPath)
    print("All unique images moved from ", dataset, " to ", uniqueImPath)
# Out:
# comparing:  ASG00051wk_0.jpg  against  ASG00051wk_0.jpg
# comparing:  ASG00051wk_0.jpg  against  ASG00051wk_1.jpg
# ASG00051wk_0.jpg similar to  ASG00051wk_1.jpg  with SSIM score:  0.8911106386371418
# comparing:  ASG00051wk_1.jpg  against  ASG00051wk_0.jpg
# comparing:  ASG00051wk_1.jpg  against  ASG00051wk_1.jpg
# comparing:  ASG00051wk_1.jpg  against  ASG00051wk_2.jpg
# ASG00051wk_1.jpg similar to  ASG00051wk_2.jpg  with SSIM score:  0.8867328524771275
# comparing:  ASG00051wk_2.jpg  against  ASG00051wk_0.jpg
# comparing:  ASG00051wk_2.jpg  against  ASG00051wk_1.jpg
# comparing:  ASG00051wk_2.jpg  against  ASG00051wk_2.jpg
# comparing:  ASG00051wk_2.jpg  against  ASG000061r_0.jpg
# comparing:  ASG00051wk_2.jpg  against  ASG000061r_1.jpg
# /home/ashepley/.local/lib/python3.6/site-packages/ipykernel_launcher.py:39: UserWarning: DEPRECATED: skimage.measure.compare_ssim has been moved to skimage.metrics.structural_similarity. It will be removed from skimage.measure in version 0.18.
# comparing:  ASG000061s_1.jpg  against  ASG00066x1_0.jpg
# comparing:  ASG000061s_1.jpg  against  ASG00066x1_1.jpg
# comparing:  ASG000061s_1.jpg  against  ASG00066x1_2.jpg
# ASG000061s_1.jpg  unique
# comparing:  ASG00066x1_0.jpg  against  ASG00051wk_0.jpg
# comparing:  ASG00066x1_0.jpg  against  ASG00051wk_1.jpg
# comparing:  ASG00066x1_0.jpg  against  ASG00051wk_2.jpg
# comparing:  ASG00066x1_0.jpg  against  ASG000061r_0.jpg
# comparing:  ASG00066x1_0.jpg  against  ASG000061r_1.jpg
# comparing:  ASG00066x1_0.jpg  against  ASG000061r_2.jpg
# comparing:  ASG00066x1_0.jpg  against  ASG000061s_0.jpg
# comparing:  ASG00066x1_0.jpg  against  ASG000061s_1.jpg
# comparing:  ASG00066x1_0.jpg  against  ASG00066x1_0.jpg
# comparing:  ASG00066x1_0.jpg  against  ASG00066x1_1.jpg
# ASG00066x1_0.jpg similar to  ASG00066x1_1.jpg  with SSIM score:  0.9036287842147978
# comparing:  ASG00066x1_1.jpg  against  ASG00051wk_0.jpg
# comparing:  ASG00066x1_1.jpg  against  ASG00051wk_1.jpg
# comparing:  ASG00066x1_1.jpg  against  ASG00051wk_2.jpg
# comparing:  ASG00066x1_1.jpg  against  ASG000061r_0.jpg
# comparing:  ASG00066x1_1.jpg  against  ASG000061r_1.jpg
# comparing:  ASG00066x1_1.jpg  against  ASG000061r_2.jpg
# comparing:  ASG00066x1_1.jpg  against  ASG000061s_0.jpg
# comparing:  ASG00066x1_1.jpg  against  ASG000061s_1.jpg
# comparing:  ASG00066x1_1.jpg  against  ASG00066x1_0.jpg
# comparing:  ASG00066x1_1.jpg  against  ASG00066x1_1.jpg
# comparing:  ASG00066x1_1.jpg  against  ASG00066x1_2.jpg
# ASG00066x1_1.jpg similar to  ASG00066x1_2.jpg  with SSIM score:  0.8993954393059079
# comparing:  ASG00066x1_2.jpg  against  ASG00051wk_0.jpg
# comparing:  ASG00066x1_2.jpg  against  ASG00051wk_1.jpg
# comparing:  ASG00066x1_2.jpg  against  ASG00051wk_2.jpg
# comparing:  ASG00066x1_2.jpg  against  ASG000061r_0.jpg
# comparing:  ASG00066x1_2.jpg  against  ASG000061r_1.jpg
# comparing:  ASG00066x1_2.jpg  against  ASG000061r_2.jpg
# comparing:  ASG00066x1_2.jpg  against  ASG000061s_0.jpg
# comparing:  ASG00066x1_2.jpg  against  ASG000061s_1.jpg
# comparing:  ASG00066x1_2.jpg  against  ASG00066x1_0.jpg
# comparing:  ASG00066x1_2.jpg  against  ASG00066x1_1.jpg
# comparing:  ASG00066x1_2.jpg  against  ASG00066x1_2.jpg
# ASG00066x1_2.jpg  unique
# Unique  ['ASG00051wk_2.jpg', 'ASG000061r_2.jpg', 'ASG000061s_1.jpg', 'ASG00066x1_2.jpg']
# Not unique  ['ASG00051wk_0.jpg', 'ASG00051wk_1.jpg', 'ASG000061r_0.jpg', 'ASG000061r_1.jpg', 'ASG000061s_0.jpg', 'ASG00066x1_0.jpg', 'ASG00066x1_1.jpg']
# All unique images moved from  ./Demo/SSIM/unsorted/  to  ./Demo/SSIM/unique/
